# %% [markdown]
# # CLIP Partial Fine-Tuning (Mughal Monuments)
# Hybrid model: zero-shot + specialist fine-tuned cluster

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %% [markdown]
# ## Upload Project ZIP

# %%
from google.colab import files
uploaded = files.upload()

# %%
import zipfile, os

zip_name = list(uploaded.keys())[0]
project_name = zip_name.replace('.zip','')

with zipfile.ZipFile(zip_name, 'r') as zip_ref:
    zip_ref.extractall()

os.chdir(project_name)
print("Working dir:", os.getcwd())

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Upload Dataset (SPECIALIST ONLY)
# Expected structure:
# data/
#   Taj Mahal/
#   Bibi Ka Maqbara/
#   Itmad-ud-Daulah/
#   Moti Masjid Agra/

# %%
uploaded = files.upload()

# %%
import zipfile

zip_name = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_name, 'r') as zip_ref:
    zip_ref.extractall()

print("Dataset ready")

# %% [markdown]
# ## Verify Dataset

# %%
import os

for cls in os.listdir('data'):
    path = os.path.join('data', cls)
    if os.path.isdir(path):
        print(cls, len(os.listdir(path)))

# %% [markdown]
# ## Train (Partial Fine-Tuning)

# %%
# !python train.py \
  --data_dir ./data \
  --epochs 5 \
  --batch_size 32 \
  --output_dir ./clip_mughal_finetuned

# %% [markdown]
# ## Save Model

# %%
# !zip -r model.zip clip_mughal_finetuned

# %%
from google.colab import files
files.download("model.zip")
